# %%
import pandas as pd

# %%
pd.read_csv('predictions.csv')
# Out:
#            Date           Coin               Model        Scope      Observed  \
# 0    2021-06-25  BTC - Bitcoin  Deep Learning LSTM  1 day ahead  31637.779297
# 1    2021-06-26  BTC - Bitcoin  Deep Learning LSTM  1 day ahead  32186.277344
# 2    2021-06-27  BTC - Bitcoin  Deep Learning LSTM  1 day ahead  34649.644531
# 3    2021-06-28  BTC - Bitcoin  Deep Learning LSTM  1 day ahead  34434.335938
# 4    2021-06-29  BTC - Bitcoin  Deep Learning LSTM  1 day ahead  35867.777344
# ..          ...            ...                 ...          ...           ...
# 725  2022-06-19  BTC - Bitcoin  Bidirectional LSTM  1 day ahead  20553.271484
# 726  2022-06-20  BTC - Bitcoin  Bidirectional LSTM  1 day ahead  20599.537109
# 727  2022-06-21  BTC - Bitcoin  Bidirectional LSTM  1 day ahead  20710.597656
# 728  2022-06-22  BTC - Bitcoin  Bidirectional LSTM  1 day ahead  19987.029297
# 729  2022-06-23  BTC - Bitcoin  Bidirectional LSTM  1 day ahead  21085.876953
#
#         Predicted
# ...

# %%
pd.read_csv('ft_importance.csv')
# Out:
#               Coin               Model        Scope        Feature  \
# 0    BTC - Bitcoin  Deep Learning LSTM  1 day ahead   Volume(t-19)
# 1    BTC - Bitcoin  Deep Learning LSTM  1 day ahead  Close_t(t-18)
# 2    BTC - Bitcoin  Deep Learning LSTM  1 day ahead      TYX(t-20)
# 3    BTC - Bitcoin  Deep Learning LSTM  1 day ahead  Close_t(t-21)
# 4    BTC - Bitcoin  Deep Learning LSTM  1 day ahead   Gtrend(t-21)
# ..             ...                 ...          ...            ...
# 715  BTC - Bitcoin  Bidirectional LSTM  1 day ahead  Close_t(t-19)
# 716  BTC - Bitcoin  Bidirectional LSTM  1 day ahead      TYX(t-17)
# 717  BTC - Bitcoin  Bidirectional LSTM  1 day ahead      TYX(t-18)
# 718  BTC - Bitcoin  Bidirectional LSTM  1 day ahead   Volume(t-16)
# 719  BTC - Bitcoin  Bidirectional LSTM  1 day ahead   Gtrend(t-17)
#
#      Importance Metric
# 0     -0.000537    mae
# 1     -0.000406    mae
# 2     -0.000342    mae
# 3     -0.000275    mae
# 4     -0.000153    mae
# ...
